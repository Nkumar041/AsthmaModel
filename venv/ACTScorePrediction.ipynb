# %% [markdown]
# # Optimised Deep Neural Network model to Predict Asthma Exacerbation based on Personalised Weather Triggers

# %%
# import required libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=DeprecationWarning)

# %%
# read the csv file 

Data = pd.read_csv('210526WeAdatasetRegression.csv')

# %% [markdown]
# # Exploratory Data Analysis

# %%
# show the dataset

Data
# Out:
#       UserNo.                        UserID      Location       Age Gender  \
# 0           1  5QBEe959GPOxv3rDNYXZXCEBOfB2      Petaling  Above 50   Male
# 1           1  5QBEe959GPOxv3rDNYXZXCEBOfB2      Petaling  Above 50   Male
# 2           1  5QBEe959GPOxv3rDNYXZXCEBOfB2      Petaling  Above 50   Male
# 3           1  5QBEe959GPOxv3rDNYXZXCEBOfB2      Petaling  Above 50   Male
# 4           1  5QBEe959GPOxv3rDNYXZXCEBOfB2      Petaling  Above 50   Male
# ...       ...                           ...           ...       ...    ...
# 1005       10  b53sAlbpdKesHxsTCiTRPL9SmGx2  Kuala Lampur     31-40   Male
# 1006       10  b53sAlbpdKesHxsTCiTRPL9SmGx2  Kuala Lampur     31-40   Male
# 1007       10  b53sAlbpdKesHxsTCiTRPL9SmGx2  Kuala Lampur     31-40   Male
# 1008       10  b53sAlbpdKesHxsTCiTRPL9SmGx2  Kuala Lampur     31-40   Male
# 1009       10  b53sAlbpdKesHxsTCiTRPL9SmGx2  Kuala Lampur     31-40   Male
#
#         OutdoorJob  OutdoorActivities SmokingHabit  Humidity  Pressure  \
# 0     Occasionally   Extremely likely           No       100      1011
# 1     Occasionally   Extremely likely           No        94      1010
# 2     Occasionally   Extremely likely           No        88      1008
# 3     Occasionally   Extremely likely           No        94      1009
# 4     Occasionally   Extremely likely           No        83      1008
# ...            ...                ...          ...       ...       ...
# 1005        Rarely  Not at all likely           No        94      1010
# 1006        Rarely  Not at all likely           No        78      1011
# 1007        Rarely  Not at all likely           No        83      1010
# 1008        Rarely  Not at all likely           No        89      1008
# 1009        Rarely  Not at all likely           No        88      1009
#
#       Temperature  UVIndex  WindSpeed  ACTScore
# 0            23.9      Low        6.7        14
# 1            25.0      Low        0.8        15
# 2            23.9  Extreme        3.1        15
# 3            22.7      Low        1.1        13
# 4            24.9      Low        5.1        15
# ...           ...      ...        ...       ...
# 1005         27.0      Low        1.3        18
# 1006         25.4      Low        1.0        18
# 1007         25.6      Low        1.0        19
# 1008         29.7  Extreme        0.9        17
# 1009         25.0      Low        2.1        19
#
# [1010 rows x 14 columns]

# %%
# get some information about the dataset

Data.info()
Data.describe().transpose()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1010 entries, 0 to 1009
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   UserNo.            1010 non-null   int64
#  1   UserID             1010 non-null   object
#  2   Location           1010 non-null   object
#  3   Age                1010 non-null   object
#  4   Gender             1010 non-null   object
#  5   OutdoorJob         1010 non-null   object
#  6   OutdoorActivities  1010 non-null   object
#  7   SmokingHabit       1010 non-null   object
#  8   Humidity           1010 non-null   int64
#  9   Pressure           1010 non-null   int64
#  10  Temperature        1010 non-null   float64
#  11  UVIndex            1010 non-null   object
#  12  WindSpeed          1010 non-null   float64
#  13  ACTScore           1010 non-null   int64
# dtypes: float64(2), int64(4), object(8)
# memory usage: 110.6+ KB
#               count         mean        std     min      25%     50%     75%  \
# UserNo.      1010.0     3.932673   2.542293     1.0     3.00     3.0     6.0
# Humidity     1010.0    81.748515  13.542801    40.0    70.00    87.0    93.0
# Pressure     1010.0  1009.264356   2.114750  1003.0  1008.00  1009.0  1011.0
# Temperature  1010.0    27.610990   2.915736    21.1    25.20    27.5    30.1
# WindSpeed    1010.0     2.373069   1.569837     0.0     1.00     2.1     3.3
# ACTScore     1010.0    16.576238   4.666969     8.0    12.25    17.0    21.0
#
#                 max
# UserNo.        10.0
# Humidity      100.0
# Pressure     1014.0
# Temperature    34.5
# WindSpeed       6.7
# ACTScore       25.0

# %%
# check if there are any Null values

Data.isnull().sum()
# Out:
# UserNo.              0
# UserID               0
# Location             0
# Age                  0
# Gender               0
# OutdoorJob           0
# OutdoorActivities    0
# SmokingHabit         0
# Humidity             0
# Pressure             0
# Temperature          0
# UVIndex              0
# WindSpeed            0
# ACTScore             0
# dtype: int64

# %%
# convert categorical data

from sklearn.preprocessing import LabelEncoder

Data['Location'] = LabelEncoder().fit_transform(Data.Location)
Data['Age'] = LabelEncoder().fit_transform(Data.Age)
Data['Gender'] = LabelEncoder().fit_transform(Data.Gender)
Data['OutdoorJob'] = LabelEncoder().fit_transform(Data.OutdoorJob)
Data['OutdoorActivities'] = LabelEncoder().fit_transform(Data.OutdoorActivities)
Data['UVIndex'] = LabelEncoder().fit_transform(Data.UVIndex)

Data
# Out:
#       UserNo.                        UserID  Location  Age  Gender  \
# 0           1  5QBEe959GPOxv3rDNYXZXCEBOfB2         4    3       1
# 1           1  5QBEe959GPOxv3rDNYXZXCEBOfB2         4    3       1
# 2           1  5QBEe959GPOxv3rDNYXZXCEBOfB2         4    3       1
# 3           1  5QBEe959GPOxv3rDNYXZXCEBOfB2         4    3       1
# 4           1  5QBEe959GPOxv3rDNYXZXCEBOfB2         4    3       1
# ...       ...                           ...       ...  ...     ...
# 1005       10  b53sAlbpdKesHxsTCiTRPL9SmGx2         3    1       1
# 1006       10  b53sAlbpdKesHxsTCiTRPL9SmGx2         3    1       1
# 1007       10  b53sAlbpdKesHxsTCiTRPL9SmGx2         3    1       1
# 1008       10  b53sAlbpdKesHxsTCiTRPL9SmGx2         3    1       1
# 1009       10  b53sAlbpdKesHxsTCiTRPL9SmGx2         3    1       1
#
#       OutdoorJob  OutdoorActivities SmokingHabit  Humidity  Pressure  \
# 0              1                  0           No       100      1011
# 1              1                  0           No        94      1010
# 2              1                  0           No        88      1008
# 3              1                  0           No        94      1009
# 4              1                  0           No        83      1008
# ...          ...                ...          ...       ...       ...
# 1005           2                  2           No        94      1010
# 1006           2                  2           No        78      1011
# 1007           2                  2           No        83      1010
# 1008           2                  2           No        89      1008
# 1009           2                  2           No        88      1009
#
#       Temperature  UVIndex  WindSpeed  ACTScore
# 0            23.9        1        6.7        14
# 1            25.0        1        0.8        15
# 2            23.9        0        3.1        15
# 3            22.7        1        1.1        13
# 4            24.9        1        5.1        15
# ...           ...      ...        ...       ...
# 1005         27.0        1        1.3        18
# 1006         25.4        1        1.0        18
# 1007         25.6        1        1.0        19
# 1008         29.7        0        0.9        17
# 1009         25.0        1        2.1        19
#
# [1010 rows x 14 columns]

# %%
# drop unnecessary data

data = Data.drop(['UserNo.', 'UserID'],axis =1)

data
# Out:
#       Location  Age  Gender  OutdoorJob  OutdoorActivities SmokingHabit  \
# 0            4    3       1           1                  0           No
# 1            4    3       1           1                  0           No
# 2            4    3       1           1                  0           No
# 3            4    3       1           1                  0           No
# 4            4    3       1           1                  0           No
# ...        ...  ...     ...         ...                ...          ...
# 1005         3    1       1           2                  2           No
# 1006         3    1       1           2                  2           No
# 1007         3    1       1           2                  2           No
# 1008         3    1       1           2                  2           No
# 1009         3    1       1           2                  2           No
#
#       Humidity  Pressure  Temperature  UVIndex  WindSpeed  ACTScore
# 0          100      1011         23.9        1        6.7        14
# 1           94      1010         25.0        1        0.8        15
# 2           88      1008         23.9        0        3.1        15
# 3           94      1009         22.7        1        1.1        13
# 4           83      1008         24.9        1        5.1        15
# ...        ...       ...          ...      ...        ...       ...
# 1005        94      1010         27.0        1        1.3        18
# 1006        78      1011         25.4        1        1.0        18
# 1007        83      1010         25.6        1        1.0        19
# 1008        89      1008         29.7        0        0.9        17
# 1009        88      1009         25.0        1        2.1        19
#
# [1010 rows x 12 columns]

# %%
# describe output variable

data['ACTScore'].describe()
# Out:
# count    1010.000000
# mean       16.576238
# std         4.666969
# min         8.000000
# 25%        12.250000
# 50%        17.000000
# 75%        21.000000
# max        25.000000
# Name: ACTScore, dtype: float64

# %%
# visualise output variable

fig = plt.figure(figsize=(10,7))
fig.add_subplot(2,1,1)
sns.distplot(data['ACTScore'])
fig.add_subplot(2,1,2)
sns.boxplot(data['ACTScore'])
plt.tight_layout()
# Out:
# /var/folders/78/0k0l12sj7tv881mzy3q878_r0000gn/T/ipykernel_1929/2516627335.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['ACTScore'])

# %%
# visualise Temperature

fig = plt.figure(figsize=(60,15),constrained_layout=False)
fig.add_subplot(2,2,1)
sns.countplot(data['Temperature'])

plt.tight_layout()

# %%
# visualise Humidity, Pressure, WindSpeed, UVIndex

fig = plt.figure(figsize=(30,10),constrained_layout=False)
fig.add_subplot(2,2,1)
sns.countplot(data['Humidity'])
fig.add_subplot(2,2,2)
sns.countplot(data['WindSpeed'])
fig.add_subplot(2,2,3)
sns.countplot(data['Pressure'])
fig.add_subplot(2,2,4)
sns.countplot(data['UVIndex'])

plt.tight_layout()

# %%
# check correlation

# data.corr()['ACTScore'].sort_values(ascending=False)

# %%
# show correlation metrix (heatmap)

# corrmat = data.corr()
# f, ax = plt.subplots(figsize=(12, 9))
# sns.heatmap(corrmat, vmax=.8, square=True);

# %%
# k = 12 # number of variables for the heatmap
# cols = corrmat.nlargest(k, 'ACTScore')['ACTScore'].index
# f, ax = plt.subplots(figsize=(20, 10))
# sns.heatmap(data[cols].corr(), vmax=.8, square=True, annot=True );

# %%
# visualise Temperature, Humidity, Pressure, WindSpeed

cols = ['ACTScore', 'Temperature', 'Humidity', 'Pressure', 'WindSpeed']
sns.pairplot(data[cols], height = 3);

# %%
# visualise UVIndex

fig = plt.figure(figsize=(25,8),constrained_layout=False)
fig.add_subplot(2,2,1)
sns.countplot(x="ACTScore", hue="UVIndex", data=Data)

plt.tight_layout()

# %% [markdown]
# # Splitting the Dataset

# %%
# define X as input features and Y as target variable 
X = data.drop(['Location','SmokingHabit', 'ACTScore'],axis =1).values
Y = data['ACTScore'].values

# %%
# split Train and Test 

from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.30, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

s_scaler = StandardScaler()
X_train = s_scaler.fit_transform(X_train.astype(np.float64))
X_test = s_scaler.transform(X_test.astype(np.float64))

# %% [markdown]
# # Deep Neural Network Regression (DNNR)

# %%
# create a DNNR model

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Dense

# %%
# add layers

model1 = Sequential()

model1.add(Dense(16, input_dim=9, activation='relu'))
model1.add(Dense(16, activation='relu'))
model1.add(Dense(1))

model1.compile(optimizer='adam',loss='mean_squared_error')

# %%
# train the model

model1.fit(x=X_train,y=Y_train,
          validation_data=(X_test,Y_test),
          batch_size=128,epochs=1000)
# Out:
# Epoch 1/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 298.6937 - val_loss: 282.3083
# Epoch 2/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 292.1996 - val_loss: 276.1726
# Epoch 3/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 285.7076 - val_loss: 269.8997
# Epoch 4/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 278.9312 - val_loss: 263.4692
# Epoch 5/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 272.0157 - val_loss: 256.8392
# Epoch 6/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 264.9074 - val_loss: 250.0277
# Epoch 7/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 257.6520 - val_loss: 243.0746
# Epoch 8/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 250.0814 - val_loss: 235.9728
# Epoch 9/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 242.3134 - val_loss: 228.6424
# Epoch 10/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 234.4749 - val_loss: 220.9821
# Epoch 11/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 226.1225 - val_loss: 213.0438
# Epoch 12/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 217.4647 - val_loss: 204.7425
# Epoch 13/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 208.5482 - val_loss: 196.0761
# Epoch 14/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 199.2221 - val_loss: 187.0922
# Epoch 15/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 189.3721 - val_loss: 177.8997
# Epoch 16/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 179.6038 - val_loss: 168.3964
# Epoch 17/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 169.3258 - val_loss: 158.8059
# Epoch 18/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 159.2270 - val_loss: 149.0378
# Epoch 19/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 148.9210 - val_loss: 139.2823
# Epoch 20/1000
# 6/6 [==============================] - 0s 3ms/step - loss:
1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.8015 - val_loss: 3.4974
# Epoch 962/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7986 - val_loss: 3.5109
# Epoch 963/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7958 - val_loss: 3.5257
# Epoch 964/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 2.8017 - val_loss: 3.5044
# Epoch 965/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 2.7934 - val_loss: 3.5084
# Epoch 966/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7956 - val_loss: 3.5107
# Epoch 967/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7891 - val_loss: 3.5166
# Epoch 968/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7866 - val_loss: 3.5163
# Epoch 969/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7881 - val_loss: 3.5154
# Epoch 970/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7827 - val_loss: 3.5122
# Epoch 971/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7824 - val_loss: 3.5092
# Epoch 972/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7845 - val_loss: 3.5130
# Epoch 973/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7875 - val_loss: 3.5155
# Epoch 974/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7858 - val_loss: 3.5164
# Epoch 975/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7900 - val_loss: 3.4962
# Epoch 976/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7703 - val_loss: 3.4953
# Epoch 977/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7756 - val_loss: 3.5063
# Epoch 978/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7763 - val_loss: 3.5000
# Epoch 979/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7727 - val_loss: 3.4906
# Epoch 980/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 2.7731 - val_loss: 3.4755
# Epoch 981/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7700 - val_loss: 3.4851
# Epoch 982/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7650 - val_loss: 3.4908
# Epoch 983/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7664 - val_loss: 3.4872
# Epoch 984/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7648 - val_loss: 3.4648
# Epoch 985/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7675 - val_loss: 3.4587
# Epoch 986/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7620 - val_loss: 3.4652
# Epoch 987/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7642 - val_loss: 3.4659
# Epoch 988/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7672 - val_loss: 3.4941
# Epoch 989/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7569 - val_loss: 3.4801
# Epoch 990/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7536 - val_loss: 3.4616
# Epoch 991/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7563 - val_loss: 3.4744
# Epoch 992/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7520 - val_loss: 3.4608
# Epoch 993/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7521 - val_loss: 3.4685
# Epoch 994/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7517 - val_loss: 3.4621
# Epoch 995/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 2.7441 - val_loss: 3.4647
# Epoch 996/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7477 - val_loss: 3.4645
# Epoch 997/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7454 - val_loss: 3.4630
# Epoch 998/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7442 - val_loss: 3.4669
# Epoch 999/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7495 - val_loss: 3.4810
# Epoch 1000/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7462 - val_loss: 3.4554

# %%
model1.summary()
# Out:
# Model: "sequential_703"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1394 (Dense)          (None, 16)                160
#
#  dense_1395 (Dense)          (None, 16)                272
#
#  dense_1396 (Dense)          (None, 1)                 17
#
# =================================================================
# Total params: 449 (1.75 KB)
# Trainable params: 449 (1.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
loss_df = pd.DataFrame(model1.history.history)
loss_df.plot(figsize=(12,8))
# Out:
# <Axes: >

# %%
# show evaluation metrics
# explained variance score: best possible score is 1 and lower values are worse

from sklearn import metrics

Y_pred1 = model1.predict(X_test)

print('Mean Absolute Error: {:.2f}'.format(metrics.mean_absolute_error(Y_test, Y_pred1)))
print('Mean Squared Error: {:.2f}'.format(metrics.mean_squared_error(Y_test, Y_pred1)))
print('Explained Variance Score: {:.2f}'.format(metrics.explained_variance_score(Y_test, Y_pred1)))
# Out:
# 10/10 [==============================] - 0s 526us/step
# Mean Absolute Error: 1.45
# Mean Squared Error: 3.46
# Explained Variance Score: 0.84

# %%
# show prediction result
fig = plt.figure(figsize = (10,5))
plt.scatter(Y_test,Y_pred1)
plt.plot(Y_test,Y_test,'r')

# %%
fig2 = plt.figure(figsize=(10,5))
residuals1 = (Y_test- Y_pred1)
sns.distplot(residuals1)
# Out:
# /var/folders/78/0k0l12sj7tv881mzy3q878_r0000gn/T/ipykernel_1929/1870692961.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(residuals1)
# <Axes: ylabel='Density'>

# %%
Y_test
# Out:
# array([13, 16, 25, 19, 20, 12, 10, 20, 24, 21, 12, 23, 21, 24, 22, 17, 23,
#        13, 13, 21, 13, 11, 10, 22, 13, 11, 17,  8, 11, 15, 18, 10, 22, 19,
#        17, 21, 14, 18, 15, 19, 15, 12, 20, 24, 10, 10,  8, 10, 19, 20, 20,
#        24, 21, 15, 18, 17, 13, 21, 10, 13, 21,  8, 10, 14, 14, 16, 13, 19,
#        17, 19, 22, 14, 10, 18, 23, 21, 21, 13, 14, 14, 14, 11, 21, 10, 20,
#         9, 12,  8, 11, 15, 19,  9, 14, 13, 12, 13, 16, 21, 20, 21, 12, 18,
#        14, 19, 24, 11,  8, 19, 21, 19, 20,  9, 11, 20, 14, 20, 19, 10, 12,
#        11, 21, 20, 21, 19, 11, 10, 17, 19, 25, 21, 20, 21, 25, 15, 18, 17,
#        21, 21, 25, 14, 22, 21, 21, 12, 21, 15, 19, 19, 11, 17, 20, 16, 13,
#        20, 12, 18, 19, 15,  9, 21, 23, 20, 24, 24, 14, 18, 20,  8, 23, 14,
#        20, 12, 17, 15, 23, 13, 18, 13,  8, 15,  9,  9, 10, 15, 14,  8, 12,
#        20, 16, 12, 20, 14, 20, 14, 19, 14, 18, 11, 18, 17, 15, 23, 14, 10,
#        11, 10, 20, 14, 19, 23, 22, 21, 21, 23, 13, 11, 17, 11, 19, 25, 10,
#        12,  8,  8, 17, 22, 15, 15, 15, 12, 15, 20,  8, 21, 15,  8, 15, 12,
#        23, 13, 18, 24, 13, 18, 13, 11, 21, 23, 25, 20, 20, 14, 21, 14, 15,
#        13, 13,  9,  9, 19, 13, 15, 11, 22, 13, 19, 20, 10, 11, 17, 14, 22,
#        17, 21, 20,  9, 11, 14, 17, 14, 22, 18, 10, 12, 20,  9, 19, 14, 17,
#        17, 23, 23, 19, 22, 25, 21, 18, 12, 23, 19, 14, 19, 12])

# %%
Y_pred1
# Out:
# array([[11.342528 ],
#        [19.251596 ],
#        [24.717884 ],
#        [17.458643 ],
#        [18.555172 ],
#        [16.147432 ],
#        [ 9.633275 ],
#        [19.661957 ],
#        [24.034908 ],
#        [19.883463 ],
#        [12.371512 ],
#        [21.171331 ],
#        [20.815336 ],
#        [24.999693 ],
#        [21.363707 ],
#        [16.080177 ],
#        [23.394964 ],
#        [14.361796 ],
#        [12.053276 ],
#        [22.162348 ],
#        [17.404024 ],
#        [ 9.3621435],
#        [ 9.438279 ],
#        [20.068718 ],
#        [11.188408 ],
#        [11.740405 ],
#        [16.764406 ],
#        [ 8.310859 ],
#        [13.125934 ],
#        [15.236167 ],
#        [19.161976 ],
#        [13.164834 ],
#        [21.28889  ],
#        [17.454191 ],
#        [11.505611 ],
#        [19.647284 ],
#        [10.998037 ],
#        [18.168318 ],
#        [18.844679 ],
#        [21.666956 ],
#        [20.45526  ],
#        [11.737209 ],
#        [18.637617 ],
#        [22.562952 ],
#        [10.806183 ],
#        [11.987378 ],
#        [11.116176 ],
#        [11.883489 ],
#        [17.071072 ],
#        [18.246284 ],
#        [21.431648 ],
#        [22.953657 ],
#        [20.925623 ],
#        [15.478606 ],
#        [13.287313 ],
#        [19.860573 ],
#        [11.148227 ],
#        [17.234957 ],
#        [16.528269 ],
#        [13.686657 ],
#        [21.038445 ],
#        [17.27272  ],
#        [10.878696 ],
#        [10.674473 ],
#        [11.94599  ],
#        [18.761095 ],
#        [12.074548 ],
#        [17.957214 ],
#        [22.841202 ],
#        [22.248442 ],
#        [19.895279 ],
#        [20.527319 ],
#        [18.506083 ],
#        [12.8288145],
#        [11.867568 ],
#        [16.64981  ],
#        [11.838284 ],
#        [18.44464  ],
#        [23.38326  ],
#        [11.808934 ],
#        [11.989543 ],
#        [ 9.1089945],
#        [11.775358 ],
#        [16.425348 ],
#        [21.32702  ],
#        [13.941291 ],
#        [16.25882  ],
#        [18.49708  ],
#        [12.894073 ],
#        [11.374495 ],
#        [21.716146 ],
#        [10.843396 ],
#        [20.392817 ],
#        [13.051602 ],
#        [ 7.0086265],
#        [18.247053 ],
#        [13.971829 ],
#        [21.744114 ],
#        [14.630475 ],
#        [19.560335 ],
#        [24.466875 ],
#        [18.708057 ],
#        [17.752375 ],
#        [14.457752 ],
#        [10.290286 ],
#        [21.16731  ],
#        [22.986038 ],
#        [24.700119 ],
#        [15.998027 ],
#        [18.55844  ],
#        [11.958039 ],
#        [20.993647 ],
#        [13.400264 ],
#        [16.305761 ],
#        [14.747104 ],
#        [13.9100895],
#        [11.137011 ],
#        [12.148341 ],
#        [18.44041  ],
#        [16.156963 ],
#        [12.3372755],
#        [11.737283 ],
#        [18.081217 ],
#        [11.70321  ],
#        [18.926569 ],
#        [20.26092  ],
#        [10.657826 ],
#        [11.402528 ],
#        [14.039622 ],
#        [13.159928 ],
#        [20.5303   ],
#        [17.408628 ],
#        [22.514235 ],
#        [23.002237 ],
#        [11.134572 ],
#        [11.767865 ],
#        [13.219426 ],
#        [15.323215 ],
#        [12.824609 ],
#        [20.030596 ],
#        [19.203451 ],
#        [10.541333 ],
#        [15.6818905],
#        [22.445415 ],
#        [11.388562 ],
#        [17.957214 ],
#        [12.634334 ],
#        [14.675758 ],
#        [16.679045 ],
#        [20.727531 ],
#        [22.96277  ],
#        [17.462326 ],
#        [22.344011 ],
#        [22.114336 ],
#        [21.888803 ],
#        [14.9274   ],
#        [10.922523 ],
#        [23.211515 ],
#        [18.087019 ],
#        [14.953322 ],
#        [20.650778 ],
#        [11.273438 ]], dtype=float32)

# %% [markdown]
# # DNNR Model Optimisation

# %% [markdown]
# ### Data scaling

# %%
# apply data standardisation

from sklearn.preprocessing import StandardScaler

TargetVariable =['ACTScore']
Predictors =['Location', 'Age', 'Gender', 'Humidity', 'Pressure', 'Temperature', 'UVIndex', 'WindSpeed', 'OutdoorJob', 'OutdoorActivities']

X = data[Predictors].values
Y = data[TargetVariable].values

PredictorScaler = StandardScaler()
TargetVarScaler = StandardScaler()

# store the fit object for later reference
PredictorScalerFit = PredictorScaler.fit(X)
TargetVarScalerFit = TargetVarScaler.fit(Y)

# generate the standardised values of X and Y
X = PredictorScalerFit.transform(X)
Y = TargetVarScalerFit.transform(Y)

# split Train and Test 
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.30, random_state=42)

# check the shapes of training and testing datasets
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (707, 10)
# (707, 1)
# (303, 10)
# (303, 1)

# %% [markdown]
# ### Optimisation algorithm

# %% [markdown]
# #### Hidden layers and hidden nodes

# %%
from scikeras.wrappers import KerasRegressor
from sklearn.model_selection import GridSearchCV
    
def FindLayerNodes(n_layers, n_layer_nodes):
    layers = []
    nodes = n_layer_nodes
    return layers

def createmodel(n_layers, n_layer_nodes):
    model = Sequential()
    n_nodes = FindLayerNodes(n_layers, n_layer_nodes)
    for i in range(1, n_layers):
        if i==1:
            model.add(Dense(n_layer_nodes, input_dim=10, activation='relu'))
        else:
            model.add(Dense(n_nodes[i], activation='relu'))
            
    model.add(Dense(1,))
    model.compile(optimizer='adam', loss='mean_squared_error')
    
    return model

model =  KerasRegressor(n_layer_nodes=10,n_layers=2,build_fn=createmodel, verbose=0)

# %%
import time

# starting time
start = time.time()

# find the optimum number of hidden layers and hidden nodes
param_grid1 = dict(n_layers=[2, 3, 4], n_layer_nodes = [10, 20, 30, 50])
grid1 = GridSearchCV(estimator = model, param_grid = param_grid1)
grid1.fit(X,Y)

# summarise results
print('Best score: %s' % grid1.best_score_)
print('Best parameters: %s' % grid1.best_params_)

# calculate time
end = time.time()
print(f'Total time taken: {end - start}')
# Out:
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# Best score: 0.34945669439317284
# Best parameters: {'n_layer_nodes': 50, 'n_layers': 2}
# Total time taken: 4.115874767303467
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 40 fits failed out of a total of 60.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 40 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py", line 760, in fit
#     self._fit(
#   File "/Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py", line 915, in _fit
#     X, y = self._initialize(X, y)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py", line 852, in _initialize
#     self.model_ = self._build_keras_model()
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py", line 429, in _build_keras_model
#     model = final_build_fn(**build_params)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/78/0k0l12sj7tv881mzy3q878_r0000gn/T/ipykernel_1929/1650866054.py", line 16, in createmodel
#     model.add(Dense(n_nodes[i], activation='relu'))
#                     ~~~~~~~^^^
# IndexError: list index out of range
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/sklearn/model_selection/_search.py:979: UserWarning: One or more of the test scores are non-finite: [-0.89481641         nan         nan -0.40227014         nan         nan
#   0.17405899         nan         nan  0.34945669         nan         nan]
#   warnings.warn(
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)

# %% [markdown]
# #### Bach size and epochs

# %%
# starting time
start = time.time()

# find the optimum bacth size
param_grid2 = dict(n_layers=[2], n_layer_nodes = [50], batch_size = [10,20])
grid2 = GridSearchCV(estimator = model, param_grid = param_grid2)
grid2.fit(X,Y)

# summarise results
print('Best score: %s' % grid2.best_score_)
print('Best parameters: %s' % grid2.best_params_)

# calculate time
end = time.time()
print(f'Total time taken: {end - start}')
# Out:
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# Best score: 0.4834131004009931
# Best parameters: {'batch_size': 20, 'n_layer_nodes': 50, 'n_layers': 2}
# Total time taken: 2.2496509552001953

# %%
# starting time
start = time.time()

# find the optimum number of epochs
param_grid2 = dict(n_layers=[2], n_layer_nodes = [50], batch_size = [10], epochs = [100,200])
grid2 = GridSearchCV(estimator = model, param_grid = param_grid2)
grid2.fit(X,Y)

# summarise results
print('Best score: %s' % grid2.best_score_)
print('Best parameters: %s' % grid2.best_params_)

# calculate time
end = time.time()
print(f'Total time taken: {end - start}')
# Out:
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# Best score: 0.6691293140739549
# Best parameters: {'batch_size': 10, 'epochs': 100, 'n_layer_nodes': 50, 'n_layers': 2}
# Total time taken: 52.79078722000122

# %% [markdown]
# #### Optimiser

# %%
# starting time
start = time.time()

# find the optimiser
from sklearn.metrics import make_scorer

def make_regression_dnnr(Optimizer_trial):
        
    model = Sequential()
    model.add(Dense(units=50, input_dim=10, activation='relu'))
    model.add(Dense(units=50, activation='relu'))
    model.add(Dense(1,))
    model.compile(loss='mean_squared_error', optimizer=Optimizer_trial)
    return model

param_grid3 = {'Optimizer_trial':['sgd', 'adam', 'rmsprop']}

model = KerasRegressor(make_regression_dnnr, verbose=False,Optimizer_trial='sgd')

# create the GridSearchCV
grid3 = GridSearchCV(estimator=model, param_grid = param_grid3)

# apply GridSearchCV for paramenters
grid3.fit(X,Y, verbose=0)

# summarise results
print('Best score: %s' % grid3.best_score_)
print('Best optimiser: %s' % grid3.best_params_)

# calculate time
end = time.time()
print(f'Total time taken: {end - start}')
# Out:
# Best score: 0.4750343994800551
# Best optimiser: {'Optimizer_trial': 'adam'}
# Total time taken: 3.3957881927490234

# %% [markdown]
# #### Loss function

# %%
# starting time
start = time.time()

# find the loss function 
from sklearn.metrics import make_scorer

def make_regression_dnnr(Loss_function):
        
    model = Sequential()
    model.add(Dense(units=50, input_dim=10, activation='relu'))
    model.add(Dense(units=50, activation='relu'))
    model.add(Dense(1,))
    model.compile(loss=Loss_function, optimizer='adam')
    return model

param_grid4 = {'Loss_function':['mae', 'mse', 'mape']}

model = KerasRegressor(make_regression_dnnr, verbose=False,Loss_function='mae')

# create the GridSearchCV
grid4 = GridSearchCV(estimator=model, param_grid = param_grid4)

# apply GridSearchCV for paramenters
grid4.fit(X,Y, verbose=0)

# summarise results
print('Best score: %s' % grid4.best_score_)
print('Best loss function: %s' % grid4.best_params_)

# calculate time
end = time.time()
print(f'Total time taken: {end - start}')
# Out:
# Best score: 0.48543189512423923
# Best loss function: {'Loss_function': 'mae'}
# Total time taken: 4.35458517074585

# %% [markdown]
# #### Weight initialiser

# %%
# starting time
start = time.time()

# find the optimum weight initialiser
def create_model(init_mode):
    # create model
    model = Sequential()
    model.add(Dense(50, input_dim=10, kernel_initializer=init_mode, activation='relu'))
    model.add(Dense(50, kernel_initializer=init_mode, activation='relu'))
    model.add(Dense(1, kernel_initializer=init_mode))
    # Compile model
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# create model
model = KerasRegressor(build_fn=create_model, epochs=100, batch_size=10, verbose=0,init_mode='uniform')

# define the grid search parameters
init_mode = ['uniform', 'normal']
param_grid5 = dict(init_mode=init_mode)
grid5 = GridSearchCV(estimator=model, param_grid =param_grid5)
grid5.fit(X, Y)

# summarise results
print('Best score: %s' % grid5.best_score_)
print('Best initialiser: %s' % grid5.best_params_)

# calculate time
end = time.time()
print(f'Total time taken: {end - start}')
# Out:
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/ModelTest/venv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# Best score: 0.7749794991991537
# Best initialiser: {'init_mode': 'normal'}
# Total time taken: 45.079638957977295

# %% [markdown]
# # Optimised DNNR

# %%
# define the optimised model

model2 = Sequential()

model2.add(Dense(units=50, input_dim=10, kernel_initializer='normal', activation='relu'))
model2.add(Dense(units=50, kernel_initializer='normal', activation='relu'))

model2.add(Dense(1, kernel_initializer='normal'))

# %%
# apply optimiser

model2.compile(loss='mean_squared_error', optimizer='adam')

# %%
# starting time
import time
start = time.time()

model2.fit(x=X_train,y=Y_train,
          validation_data=(X_test,Y_test),
          batch_size=10,epochs=100)

# calculate time
end = time.time()
print(f'Total time taken: {end - start}')
# Out:
# Epoch 1/100
# 71/71 [==============================] - 0s 1ms/step - loss: 0.7100 - val_loss: 0.3033
# Epoch 2/100
# 71/71 [==============================] - 0s 828us/step - loss: 0.2793 - val_loss: 0.2456
# Epoch 3/100
# 71/71 [==============================] - 0s 839us/step - loss: 0.2541 - val_loss: 0.2190
# Epoch 4/100
# 71/71 [==============================] - 0s 801us/step - loss: 0.2351 - val_loss: 0.2123
# Epoch 5/100
# 71/71 [==============================] - 0s 793us/step - loss: 0.2317 - val_loss: 0.1942
# Epoch 6/100
# 71/71 [==============================] - 0s 790us/step - loss: 0.2179 - val_loss: 0.1940

# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1652 (Dense)          (None, 50)                550
#
#  dense_1653 (Dense)          (None, 50)                2550
#
#  dense_1654 (Dense)          (None, 1)                 51
#
# =================================================================
# Total params: 3151 (12.31 KB)
# Trainable params: 3151 (12.31 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
loss_df = pd.DataFrame(model2.history.history)
loss_df.plot(figsize=(12,8))
# Out:
# <Axes: >

# %%
Y_pred2 = model2.predict(X_test)
X_test
# Out:
# 10/10 [==============================] - 0s 541us/step
# array([[-1.14715719, -0.69796586, -0.78815468, ...,  1.29181244,
#         -1.85357435, -0.37089321],
#        [ 0.87959866, -0.69796586, -0.78815468, ...,  0.59075557,
#          0.17471394, -0.37089321],
#        [-1.14715719, -0.69796586, -0.78815468, ..., -1.13002037,
#         -1.85357435, -0.37089321],
#        ...,
#        [ 0.20401338,  1.71073182,  1.26878648, ...,  1.10061511,
#          0.17471394, -0.37089321],
#        [ 0.20401338,  1.71073182,  1.26878648, ...,  0.14462847,
#          0.17471394, -0.37089321],
#        [ 0.87959866, -0.69796586, -0.78815468, ...,  1.86540442,
#          0.17471394, -0.37089321]])

# %%
# evaluation metrics
# explained variance score: best possible score is 1 and lower values are worse
from sklearn import metrics

print('Mean Absolute Error: {:.2f}'.format(metrics.mean_absolute_error(Y_test, Y_pred2)))
print('Mean Squared Error: {:.2f}'.format(metrics.mean_squared_error(Y_test, Y_pred2)))
print('Explained Variance Score: {:.2f}'.format(metrics.explained_variance_score(Y_test,Y_pred2)))
# Out:
# Mean Absolute Error: 0.22
# Mean Squared Error: 0.10
# Explained Variance Score: 0.90

# %%
# show prediction result
fig3 = plt.figure(figsize = (10,5))
plt.scatter(Y_test,Y_pred2)
plt.plot(Y_test,Y_test,'r')

# %%
# show residuals
fig4 = plt.figure(figsize = (10,5))
residuals2 = (Y_test - Y_pred2)
sns.distplot(residuals2)
# Out:
# /var/folders/78/0k0l12sj7tv881mzy3q878_r0000gn/T/ipykernel_1929/2408565348.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(residuals2)
# <Axes: ylabel='Density'>

# %%
# generate predictions on testing set
Predictions = model2.predict(X_test)
 
# scale the predicted ACTScore back to original ACTScore scale
Predictions = TargetVarScalerFit.inverse_transform(Predictions)
 
# scale the Y_test ACTScore data back to original ACTScore scale
Y_test_orig = TargetVarScalerFit.inverse_transform(Y_test)
 
# scale the test data back to original scale
Test_Data = PredictorScalerFit.inverse_transform(X_test)
 
TestingData = pd.DataFrame(data = Test_Data, columns = Predictors)
TestingData['ACTScore'] = Y_test_orig
TestingData['PredictedACTScore'] = Predictions
# Out:
# 10/10 [==============================] - 0s 1ms/step

# %%
# compute the total accuracy from absolute error
Absolute_Error = 100 * (abs(TestingData['ACTScore'] - TestingData['PredictedACTScore']) / TestingData['ACTScore'])
TestingData['APE'] = Absolute_Error

print('The Accuracy of the optimised DNNR model is:', 100-np.mean(Absolute_Error))
# Out:
# The Accuracy of the optimised DNNR model is: 92.9646535137447

# %%
# compare the prediction with real ACTScore for the first column
ACT_prediction = data['ACTScore'][0]

print ("Original ACT Score = 14")
print ("Predicted ACT Score =", ACT_prediction)
# Out:
# Original ACT Score = 14
# Predicted ACT Score = 14
